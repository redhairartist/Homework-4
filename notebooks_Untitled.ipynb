# %%
#Для каждой газеты из списка напишите формат указанной даты для перевода в объект datetime

# %%
from datetime import datetime

date_string = 'Wednesday, October 2, 2002'
date_object = datetime.strptime(date_string, '%A, %B %d, %Y')
print(date_object)
# Out:
# 2002-10-02 00:00:00

# %%
from datetime import datetime

date_string = 'Friday, 11.10.13'
date_object = datetime.strptime(date_string, '%A, %d.%m.%y')
print(date_object)
# Out:
# 2013-10-11 00:00:00

# %%
from datetime import datetime

date_string = 'Thursday, 18 August 1977'
date_object = datetime.strptime(date_string, '%A, %d %B %Y')
print(date_object)
# Out:
# 1977-08-18 00:00:00

# %%
The Moscow Times = 'Wednesday, October 2, 2002'
The Guardian = 'Friday, 11.10.13'
Daily News = 'Thursday, 18 August 1977'
